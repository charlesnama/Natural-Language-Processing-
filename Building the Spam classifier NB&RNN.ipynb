# %% [markdown]
# <ul>1 We're going to classify visualize the distribution </ul>
# <ul>2 Look at the length of spam vs the length of ham messages</ul>
# <ul>3 Group to see the top 10 most sent messages </ul>
# <ul>4 We'll extract the various most common spam words</ul>
# <ul>5 The preprocessing</ul>
# <ul>6 The modelling process</ul>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.model_selection import train_test_split
from wordcloud import WordCloud
import seaborn as sns
# %matplotlib inline

# Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('/Users/mac/Downloads/spam.csv', encoding='ISO-8859-1')
data.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
data = data.drop(labels = ["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis = 1)

# %%
data.columns = ['Label','Text']

# %%
data.head()
# Out:
#   Label                                               Text
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
#Let's check the distribution 
fig,axs = plt.subplots(1,2, figsize = (15,6))
data.Label.value_counts().plot(kind='pie',ax=axs[1],autopct='%1.1f%%', explode=[0,0.1],shadow=True)
data.Label.value_counts().plot(kind='bar', ax=axs[0], color=['g','r'])
plt.title('Spam and Non Spam')
plt.ylabel('')
plt.legend(['Ham','Spam'])
plt.show()

# %% [markdown]
# <b>Intuition</b><br>
# As expected most of the data present aren't spam messages

# %% [markdown]
# #### Let's see look into length of spam vs non spam messages, to satisfy a stereotype that spam messages are long.

# %%
data['TextLength'] = data.Text.apply(len)

fig, axs = plt.subplots(1,2, figsize=(15,6))

sns.distplot(data[data.Label=='spam']['TextLength'], bins = 20,ax=axs[0])
axs[0].set_xlabel("Ham Message Word Length")


sns.distplot(data[data.Label =='ham']['TextLength'], bins = 20, ax=axs[1])
axs[1].set_xlabel("Spam Message Word Length")

plt.show()

# %% [markdown]
# <b>Intuition</b><br>
# Apparently spam messages are always very long. In this case our assumption proved accurate

# %%
data.head()
# Out:
#   Label                                               Text  TextLength
# 0   ham  Go until jurong point, crazy.. Available only ...         111
# 1   ham                      Ok lar... Joking wif u oni...          29
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...         155
# 3   ham  U dun say so early hor... U c already then say...          49
# 4   ham  Nah I don't think he goes to usf, he lives aro...          61

# %% [markdown]
# #### Let's take a look at the most commonly sent messages

# %%
Most_sent = data.groupby('Text')['Label'].agg([len,np.max]).sort_values(by='len',ascending=True)
Most_sent.head(10)
# Out:
#                                                     len  amax
# Text
#  &lt;#&gt;  in mca. But not conform.                  1   ham
# Right on brah, see you later                          1   ham
# Right it wasnt you who phoned it was someone wi...    1   ham
# Reply with your name and address and YOU WILL R...    1  spam
# Reply to win å£100 weekly! Where will the 2006 ...    1  spam
# Reply to win å£100 weekly! What professional sp...    1  spam
# Reminder: You have not downloaded the content y...    1  spam
# Remind me how to get there and I shall do so          1   ham
# Remember to ask alex about his pizza                  1   ham
# Remember on that day..                                1   ham

# %% [markdown]
# #### It will be nice to sort out some spam words and have a feel

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string 
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
spam_messages = data[data["Label"] == "spam"]["Text"]
ham_messages = data[data["Label"] == "ham"]["Text"]

spam_words = []
ham_words = []
 

def extractSpamWords(spamMessages):
    global spam_words
    words = [word.lower() for word in word_tokenize(spamMessages) if word.lower() not in stopwords.words("english") and word.lower().isalpha()]
    spam_words = spam_words + words
    
def extractHamWords(hamMessages):
    global ham_words
    words = [word.lower() for word in word_tokenize(hamMessages) if word.lower() not in stopwords.words("english") and word.lower().isalpha()]
    ham_words = ham_words + words

spam_messages.apply(extractSpamWords)
ham_messages.apply(extractHamWords)
# Out:
# 0       None
# 1       None
# 3       None
# 4       None
# 6       None
#         ...
# 5565    None
# 5568    None
# 5569    None
# 5570    None
# 5571    None
# Name: Text, Length: 4825, dtype: object

# %%
from wordcloud import WordCloud

spam_wordcloud = WordCloud(width=600, height=400).generate(" ".join(spam_words))
plt.figure( figsize=(10,8), facecolor='k')
plt.imshow(spam_wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# #### The preprocessing steps of stemming, stopword/punctuation removal

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
def cleanText(message):
    
    message = message.translate(str.maketrans('', '', string.punctuation))
    words = [lemmatizer.lemmatize(word) for word in message.split() if word.lower() not in stopwords.words("english")]
    
    return " ".join(words)

data["Text"] = data["Text"].apply(cleanText)
data.head(10)
# Out:
#   Label                                               Text  TextLength
# 0   ham  Go jurong point crazy Available bugis n great ...         111
# 1   ham                            Ok lar Joking wif u oni          29
# 2  spam  Free entry 2 wkly comp win FA Cup final tkts 2...         155
# 3   ham                U dun say early hor U c already say          49
# 4   ham           Nah dont think go usf life around though          61
# 5  spam  FreeMsg Hey darling 3 week word back Id like f...         148
# 6   ham      Even brother like speak treat like aid patent          77
# 7   ham  per request Melle Melle Oru Minnaminunginte Nu...         160
# 8  spam  WINNER valued network customer selected receiv...         158
# 9  spam  mobile 11 month U R entitled Update latest col...         154

# %% [markdown]
# <b> Performed the lemmatization process and it looks worse, i'll rather use the text as it is for the model</b><br>
# Let's build a Naive Bayes Classifier and see how it performs

# %%
# Let's create a column with an encoded format for the Target
data['Spam'] = data['Label'].map({'ham': 0, 'spam': 1})
Y = data['Spam'].values

# %% [markdown]
# <b>We're going to use both CountVectorizer and TFidf vectorizer to calculate the features</b>

# %%
df_train, df_test, Ytrain, Ytest = train_test_split(data['Text'], Y, test_size=0.33)

# %%
tfidf = TfidfVectorizer(decode_error='ignore')
Xtrain = tfidf.fit_transform(df_train)
Xtest = tfidf.transform(df_test)

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
# create the model, train it, print scores
model = MultinomialNB()
model.fit(Xtrain, Ytrain)
print("train score:", model.score(Xtrain, Ytrain))
print("test score:", model.score(Xtest, Ytest))
# exit()
# Out:
# train score: 0.9737476560407179
# test score: 0.957041870581838

# %% [markdown]
# <b>Case II</b>

# %%
count_vectorizer = CountVectorizer(decode_error='ignore')
Xtrain = count_vectorizer.fit_transform(df_train)
Xtest = count_vectorizer.transform(df_test)

# %%
model = MultinomialNB()
model.fit(Xtrain, Ytrain)
print("train score:", model.score(Xtrain, Ytrain))
print("test score:", model.score(Xtest, Ytest))
# exit()
# Out:
# train score: 0.9930350924189659
# test score: 0.9798803697661773

# %%
# What did we miss?
X = tfidf.transform(data['Text'])
data['predictions'] = model.predict(X)

# %%
Wrongly_classified = data[(data['predictions'] == 0) & (data['Spam'] == 1)]['Text']
for msg in Wrongly_classified:
    print(msg)
# Out:
# SMS ac Sptv New Jersey Devils Detroit Red Wings play Ice Hockey Correct Incorrect End Reply END SPTV
# hear new Divorce Barbie come Kens stuff
# SMS ac Blind Date 4U Rodds1 21m Aberdeen United Kingdom Check httpimg sm acWicmb3cktz8r74 Blind Dates send HIDE
# credit topped httpwwwbubbletextcom renewal Pin tgxxrz
# SMS ac sun0819 post HELLOYou seem cool
# realize 40 year well thousand old lady running around tattoo
# Talk sexy Make new friend fall love world discreet text dating service text VIP 83110 see could meet
# Hello need posh bird chap user trial prod champneys put need address dob asap Ta r
# Filthy story GIRLS waiting
# Dont forget place many FREE Requests 1stchoicecouk wish Information call 08707808226
# 1 new voicemail Please call 08719181503
# 1 new voicemail Please call 08719181513
# Win newest ÛÏHarry Potter Order Phoenix Book 5 reply HARRY answer 5 question chance first among reader
# Ur balance å£500 Ur next question sang Uptown Girl 80 2 answer txt ur ANSWER 83600 Good luck
# sale arsenal dartboard Good condition double treble
# Hi LUCY Hubby meetins day Fri B alone hotel U fancy cumin Pls leave msg 2day 09099726395 Lucy x Callså£1minMobsmoreLKPOBOX177HP51FL
# Thanks Vote sing along star Karaoke mobile FREE link reply SING
# 0ANETWORKS allow company bill SMS responsible supplier
# Would like see XXX pic hot nearly banned uk
# TheMobYo yo yoHere come new selection hot downloads member get FREE click open next link sent ur fone
# FreeMsg Hey Im Buffy 25 love satisfy men Home alone feeling randy Reply 2 C PIX QlynnBV Help08700621170150p msg Send stop stop txts
# Babe U want dont u baby Im nasty thing 4 filthyguys Fancy rude time sexy bitch go slo n hard Txt XXX SLO4msgs
# Guess IThis first time created web page WWWASJESUSCOM read wrote Im waiting opinion want friend 11
# Hello darling today would love chat dont tell look like sexy
# 88066 LOST å£12 HELP
# come take little time child afraid dark become teenager want stay night
# INTERFLORA åÒIts late order Interflora flower christmas call 0800 505060 place order Midnight tomorrow
# ROMCAPspam Everyone around responding well presence since warm outgoing bringing real breath sunshine
# ever notice youre driving anyone going slower idiot everyone driving faster maniac
# 1 new voicemail Please call 08719181513
# Sorry missed call let talk time Im 07090201529
# LIFE never much fun great came made truly special wont forget enjoy one gbpsms
# new 2 club dont fink met yet B gr8 2 C U Please leave msg 2day wiv ur area 09099726553 reply promised CARLIE x Callså£1minMobsmore LKPOBOX177HP51FL
# heard U4 Call night knickers Make beg like U last time 01223585236 XX Luv Nikiyu4net
# Bloomberg Message center 447797706009 wait Apply future httpcareers bloombergcom
# Xmas New Years Eve ticket sale club day 10am till 8pm Thurs Fri Sat night week Theyre selling fast
# Bloomberg Message center 447797706009 wait Apply future httpcareers bloombergcom
# Win newest åÒHarry Potter Order Phoenix Book 5 reply HARRY answer 5 question chance first among reader
# Oh god Ive found number Im glad text back xafter msg cst std ntwk chg å£150
# link picture sent also use httpalto18coukwavewaveaspo44345
# Simpsons Movie released July 2007 name band died start film AGreen Day BBlue Day CRed Day Send B C
# Missed call alert number called left message 07008009200
# accordingly repeat text word ok mobile phone send
# thesmszonecom let send free anonymous masked messagesim sending message theredo see potential abuse
# Ur balance å£600 Next question Complete landmark Big Bob B Barry C Ben Text B C 83738 Good luck
# Want explicit SEX 30 sec Ring 02073162414 Costs 20pmin
# Money wining number 946 wot next
# Cashbincouk Get lot cash weekend wwwcashbincouk Dear Welcome weekend got biggest best EVER cash give away
# Goal Arsenal 4 Henry 7 v Liverpool 2 Henry score simple shot 6 yard pas Bergkamp give Arsenal 2 goal margin 78 min
# Hi Amy sending free phone number couple day give access adult party
# TheMobHit link get premium Pink Panther game new 1 Sugababes crazy Zebra animation badass Hoody wallpaperall 4 FREE
# 1 new message Please call 08715205273
# datingi two started sent text talk sport radio last week connection think coincidence
# 1 new message Call 02070836089
# Santa Calling Would little one like call Santa Xmas eve Call 09058094583 book time
# sparkling shopping break 45 per person call 0121 2025050 visit wwwshortbreaksorguk
# Want explicit SEX 30 sec Ring 02073162414 Costs 20pmin Gsex POBOX 2667 WC1N 3XX

# %%
# things that should not be spam
not_actually_spam = data[(data['predictions'] == 1) & (data['Spam'] == 0)]['Text']
for msg in not_actually_spam:
  print(msg)

# %% [markdown]
# <b>Building the second model using RNN<b>

# %%
from sklearn.preprocessing import LabelEncoder
from keras.models import Model
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding
from keras.optimizers import RMSprop
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping

# %%
X = data.Text
Y = data.Label
le = LabelEncoder()
Y = le.fit_transform(Y)
Y = Y.reshape(-1,1)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.30)

# %%
max_words = 1000
max_len = 150
tok = Tokenizer(num_words=max_words)
tok.fit_on_texts(X_train)
sequences = tok.texts_to_sequences(X_train)
sequences_matrix = sequence.pad_sequences(sequences,maxlen=max_len)

# %%
def RNN():
    inputs = Input(name='inputs',shape=[max_len])
    layer = Embedding(max_words,50,input_length=max_len)(inputs)
    layer = LSTM(64)(layer)
    layer = Dense(256,name='FC1')(layer)
    layer = Activation('relu')(layer)
    layer = Dropout(0.5)(layer)
    layer = Dense(1,name='out_layer')(layer)
    layer = Activation('sigmoid')(layer)
    model = Model(inputs=inputs,outputs=layer)
    return model

# %%
model = RNN()
model.summary()
model.compile(loss='binary_crossentropy',optimizer=RMSprop(),metrics=['accuracy'])
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          [(None, 150)]             0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 150, 50)           50000
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                29440
# _________________________________________________________________
# FC1 (Dense)                  (None, 256)               16640
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# out_layer (Dense)            (None, 1)                 257
# _________________________________________________________________
# activation_3 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 96,337
# Trainable params: 96,337
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(sequences_matrix,Y_train,batch_size=128,epochs=10,
          validation_split=0.2,callbacks=[EarlyStopping(monitor='val_loss',min_delta=0.0001)])
# Out:
# Epoch 1/10
# 25/25 [==============================] - 3s 126ms/step - loss: 0.3771 - accuracy: 0.8519 - val_loss: 0.2804 - val_accuracy: 0.9628
# Epoch 2/10
# 25/25 [==============================] - 3s 114ms/step - loss: 0.1461 - accuracy: 0.9596 - val_loss: 0.1116 - val_accuracy: 0.9718
# Epoch 3/10
# 25/25 [==============================] - 3s 113ms/step - loss: 0.0657 - accuracy: 0.9833 - val_loss: 0.0722 - val_accuracy: 0.9821
# Epoch 4/10
# 25/25 [==============================] - 3s 113ms/step - loss: 0.0445 - accuracy: 0.9872 - val_loss: 0.0685 - val_accuracy: 0.9821
# Epoch 5/10
# 25/25 [==============================] - 3s 117ms/step - loss: 0.0319 - accuracy: 0.9894 - val_loss: 0.0730 - val_accuracy: 0.9821

# %%
test_sequences = tok.texts_to_sequences(X_test)
test_sequences_matrix = sequence.pad_sequences(test_sequences,maxlen=max_len)

# %%
accr = model.evaluate(test_sequences_matrix,Y_test)
# Out:
# 53/53 [==============================] - 1s 14ms/step - loss: 0.0655 - accuracy: 0.9839

# %%
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(accr[0],accr[1]))
# Out:
# Test set
#   Loss: 0.066
#   Accuracy: 0.984
